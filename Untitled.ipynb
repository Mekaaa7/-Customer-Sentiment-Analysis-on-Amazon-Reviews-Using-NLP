# %%
# Basic Libraries
import pandas as pd
import numpy as np

# Text Processing
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("reviews.csv")
df = df.sample(n=200000,random_state=42)
df.shape
# Out:
# (200000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, 165256 to 73597
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      200000 non-null  int64
#  1   ProductId               200000 non-null  object
#  2   UserId                  200000 non-null  object
#  3   ProfileName             199993 non-null  object
#  4   HelpfulnessNumerator    200000 non-null  int64
#  5   HelpfulnessDenominator  200000 non-null  int64
#  6   Score                   200000 non-null  int64
#  7   Time                    200000 non-null  int64
#  8   Summary                 199989 non-null  object
#  9   Text                    200000 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 16.8+ MB

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName                7
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   11
# Text                       0
# dtype: int64

# %%
df = df[['Score', 'Text']]
df.head()
# Out:
#         Score                                               Text
# 165256      5  Having tried a couple of other brands of glute...
# 231465      5  My cat loves these treats. If ever I can't fin...
# 427827      3  A little less than I expected.  It tends to ha...
# 433954      2  First there was Frosted Mini-Wheats, in origin...
# 70260       5  and I want to congratulate the graphic artist ...

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def convert_sentiment(score):
    if score <= 2:
        return 'Negative'
    elif score >= 4:
        return 'Positive'
    else:
        return 'Neutral'

df['Sentiment'] = df['Score'].apply(convert_sentiment)

# %%
df = df[df['Sentiment'] != 'Neutral']

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    156413
# Negative     28558
# Name: count, dtype: int64

# %%
positive = df[df['Sentiment'] == 'Positive']
negative = df[df['Sentiment'] == 'Negative']

positive_sample = positive.sample(n=28558, random_state=42)

df = pd.concat([positive_sample, negative])

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    28558
# Negative    28558
# Name: count, dtype: int64

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()  # lowercase
    text = re.sub(r'[^a-zA-Z]', ' ', text)  # remove special characters & numbers
    text = text.split()  # tokenize
    text = [lemmatizer.lemmatize(word) for word in text if word not in stop_words]
    return " ".join(text)

df['Cleaned_Text'] = df['Text'].apply(clean_text)

# %%
df[['Text','Cleaned_Text']].head()
# Out:
#                                                      Text  \
# 498902  I am a very picky eater which seriously limits...
# 42225   This blend is one of Starbucks' gentler blends...
# 312212  I appreciate being able to purchase this item ...
# 226883  Good stuff. I despise the taste of processed s...
# 422437  cats love it which is all that matters. so gla...
#
#                                              Cleaned_Text
# 498902  picky eater seriously limit protein intake tra...
# 42225   blend one starbucks gentler blend like taste s...
# 312212  appreciate able purchase item case favorite wi...
# 226883  good stuff despise taste processed sweetners h...
# 422437                     cat love matter glad got order

# %%
X = df['Cleaned_Text']
y = df['Sentiment']

# %%
vectorizer = TfidfVectorizer(max_features=10000)

X_tfidf = vectorizer.fit_transform(X)

# %%
X_tfidf.shape
# Out:
# (57116, 10000)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, 
    test_size=0.2, 
    random_state=42
)

# %%
X_train.shape, X_test.shape
# Out:
# ((45692, 10000), (11424, 10000))

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.885766806722689
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.89      0.89      5749
#     Positive       0.89      0.88      0.88      5675
#
#     accuracy                           0.89     11424
#    macro avg       0.89      0.89      0.89     11424
# weighted avg       0.89      0.89      0.89     11424

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[5119,  630],
#        [ 675, 5000]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Negative','Positive'],
            yticklabels=['Negative','Positive'])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
def predict_sentiment(review):
    review_cleaned = clean_text(review)
    review_vectorized = vectorizer.transform([review_cleaned])
    prediction = model.predict(review_vectorized)
    return prediction[0]

# %%
predict_sentiment("This product is absolutely amazing and works perfectly")
# Out:
# 'Positive'

# %%
predict_sentiment("This is the worst product I have ever bought")
# Out:
# 'Negative'

# %%
df['Predicted_Sentiment'] = model.predict(X_tfidf)

# %%
df.head()
# Out:
#         Score                                               Text Sentiment  \
# 498902      4  I am a very picky eater which seriously limits...  Positive
# 42225       5  This blend is one of Starbucks' gentler blends...  Positive
# 312212      5  I appreciate being able to purchase this item ...  Positive
# 226883      4  Good stuff. I despise the taste of processed s...  Positive
# 422437      5  cats love it which is all that matters. so gla...  Positive
#
#                                              Cleaned_Text Predicted_Sentiment
# 498902  picky eater seriously limit protein intake tra...            Positive
# 42225   blend one starbucks gentler blend like taste s...            Positive
# 312212  appreciate able purchase item case favorite wi...            Positive
# 226883  good stuff despise taste processed sweetners h...            Positive
# 422437                     cat love matter glad got order            Positive

# %%
df['Review_Length'] = df['Text'].apply(len)

# %%
df.to_csv("sentiment_analysis_final.csv", index=False)
